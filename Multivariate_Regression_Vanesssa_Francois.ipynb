# %% [markdown]
# <a href="https://colab.research.google.com/github/vfrancois9/Audencia/blob/main/Multivariate_Regression_Vanesssa_Francois.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns                       #visualisation
import matplotlib.pyplot as plt             #visualisation
# %matplotlib inline     
sns.set(color_codes=True)

# %%
df = pd.read_csv("Credit.csv")
# To display the top 10 rows 
df.head(10)
# Out:
#    Unnamed: 0   Income  Limit  Rating  Cards  Age  Education  Gender Student  \
# 0           1   14.891   3606     283      2   34         11    Male      No
# 1           2  106.025   6645     483      3   82         15  Female     Yes
# 2           3  104.593   7075     514      4   71         11    Male      No
# 3           4  148.924   9504     681      3   36         11  Female      No
# 4           5   55.882   4897     357      2   68         16    Male      No
# 5           6   80.180   8047     569      4   77         10    Male      No
# 6           7   20.996   3388     259      2   37         12  Female      No
# 7           8   71.408   7114     512      2   87          9    Male      No
# 8           9   15.125   3300     266      5   66         13  Female      No
# 9          10   71.061   6819     491      3   41         19  Female     Yes
#
#   Married         Ethnicity  Balance
# 0     Yes         Caucasian      333
# 1     Yes             Asian      903
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# Income        float64
# Limit           int64
# Rating          int64
# Cards           int64
# Age             int64
# Education       int64
# Gender         object
# Student        object
# Married        object
# Ethnicity      object
# Balance         int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  400 non-null    int64
#  1   Income      400 non-null    float64
#  2   Limit       400 non-null    int64
#  3   Rating      400 non-null    int64
#  4   Cards       400 non-null    int64
#  5   Age         400 non-null    int64
#  6   Education   400 non-null    int64
#  7   Gender      400 non-null    object
#  8   Student     400 non-null    object
#  9   Married     400 non-null    object
#  10  Ethnicity   400 non-null    object
#  11  Balance     400 non-null    int64
# dtypes: float64(1), int64(7), object(4)
# memory usage: 37.6+ KB

# %%
sns.regplot(x="Limit", y="Income", data=df, line_kws={'color':'red'})
plt.show()

# %%
sns.regplot(x="Rating", y="Income", data=df, line_kws={'color':'red'})
plt.show()

# %%
sns.regplot(x="Cards", y="Income", data=df, line_kws={'color':'red'})
plt.show()

# %%
sns.regplot(x="Age", y="Income", data=df, line_kws={'color':'red'})
plt.show()

# %%
sns.regplot(x="Education", y="Income", data=df, line_kws={'color':'red'})
plt.show()

# %%
sns.regplot(x="Balance", y="Income", data=df, line_kws={'color':'red'})
plt.show()

# %%
import statsmodels.formula.api as smf
lin_model = smf.ols("Income ~ Limit + Rating + Cards + Age + Education + Balance", data=df).fit()
lin_model.summary()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Income   R-squared:                       0.819
# Model:                            OLS   Adj. R-squared:                  0.816
# Method:                 Least Squares   F-statistic:                     296.7
# Date:                Tue, 22 Mar 2022   Prob (F-statistic):          1.48e-142
# Time:                        05:14:05   Log-Likelihood:                -1649.9
# No. Observations:                 400   AIC:                             3314.
# Df Residuals:                     393   BIC:                             3342.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...

# %%
import statsmodels.formula.api as smf
lin_model = smf.ols("Income ~ Limit + Rating + Age +  Balance", data=df).fit()
lin_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Income   R-squared:                       0.819
# Model:                            OLS   Adj. R-squared:                  0.817
# Method:                 Least Squares   F-statistic:                     447.2
# Date:                Tue, 22 Mar 2022   Prob (F-statistic):          3.50e-145
# Time:                        05:18:16   Log-Likelihood:                -1650.0
# No. Observations:                 400   AIC:                             3310.
# Df Residuals:                     395   BIC:                             3330.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -41.4838      3.774    -10.993      0.000     -48.903     -34.065
# ...

# %%
temp_data = pd.DataFrame(dict(Balance=df.Balance, residual=lin_model.resid))
graph = sns.lmplot(x='Balance', y='residual', data=temp_data, lowess=True, line_kws={'color':'red'})

# %%
sns.distplot(lin_model.get_influence().resid_studentized_internal)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import statsmodels.formula.api as smf
lin_model = smf.ols("Income ~ Limit + Rating +   Balance + np.square(Balance)", data=df).fit()
lin_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Income   R-squared:                       0.855
# Model:                            OLS   Adj. R-squared:                  0.854
# Method:                 Least Squares   F-statistic:                     583.6
# Date:                Tue, 22 Mar 2022   Prob (F-statistic):          2.75e-164
# Time:                        05:19:57   Log-Likelihood:                -1605.4
# No. Observations:                 400   AIC:                             3221.
# Df Residuals:                     395   BIC:                             3241.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...

# %%
temp_data = pd.DataFrame(dict(Limit=df.Limit, residual=lin_model.resid))
graph = sns.lmplot(x='Limit', y='residual', data=temp_data, lowess=True, line_kws={'color':'red'})

# %%
import statsmodels.formula.api as smf
lin_model = smf.ols("Income ~ Limit + np.square(Limit)+ np.power(Limit,3)+ Balance ", data=df).fit()
lin_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Income   R-squared:                       0.881
# Model:                            OLS   Adj. R-squared:                  0.879
# Method:                 Least Squares   F-statistic:                     728.0
# Date:                Tue, 22 Mar 2022   Prob (F-statistic):          9.50e-181
# Time:                        05:20:35   Log-Likelihood:                -1567.0
# No. Observations:                 400   AIC:                             3144.
# Df Residuals:                     395   BIC:                             3164.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...

# %%
temp_data = pd.DataFrame(dict(fitted_values=lin_model.fittedvalues, residual=lin_model.resid))
graph = sns.lmplot(x='fitted_values', y='residual', data=temp_data, lowess=True, line_kws={'color':'red'})
plt.show()

# %%
import statsmodels.formula.api as smf
lin_model = smf.ols("Income ~ Limit + np.square(Limit)+ np.power(Limit,3)+ Balance + Rating", data=df).fit()
lin_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Income   R-squared:                       0.882
# Model:                            OLS   Adj. R-squared:                  0.881
# Method:                 Least Squares   F-statistic:                     590.7
# Date:                Tue, 22 Mar 2022   Prob (F-statistic):          1.51e-180
# Time:                        05:25:44   Log-Likelihood:                -1564.1
# No. Observations:                 400   AIC:                             3140.
# Df Residuals:                     394   BIC:                             3164.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...
